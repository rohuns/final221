# %%
import pandas as pd
import warnings, datetime
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "last_expr"
warnings.filterwarnings("ignore")

# %%
import random

movies = pd.read_csv('movie_metadata.csv')
movies['genres'] = movies.apply(lambda row: random.choice(row.genres.replace('|', ' ').split()), axis=1)
movies
# Out:
#                  color       director_name  num_critic_for_reviews  duration  \
# 0                Color       James Cameron                   723.0     178.0
# 1                Color      Gore Verbinski                   302.0     169.0
# 2                Color          Sam Mendes                   602.0     148.0
# 3                Color   Christopher Nolan                   813.0     164.0
# 4                  NaN         Doug Walker                     NaN       NaN
# 5                Color      Andrew Stanton                   462.0     132.0
# 6                Color           Sam Raimi                   392.0     156.0
# 7                Color        Nathan Greno                   324.0     100.0
# 8                Color         Joss Whedon                   635.0     141.0
# 9                Color         David Yates                   375.0     153.0
# 10               Color         Zack Snyder                   673.0     183.0
# ...

# %%
all_actors = set(movies['actor_1_name'].tolist() + movies['actor_2_name'].tolist() + movies['actor_3_name'].tolist())
all_actors
len(all_actors)
# Out:
# 6256

# %%
missing_df = movies.isnull().sum(axis=0).reset_index()
missing_df.columns = ['variable', 'missing values']
missing_df['filling factor (%)']=(movies.shape[0]-missing_df['missing values'])/movies.shape[0]*100
missing_df.sort_values('filling factor (%)').reset_index(drop = True)
# Out:
#                      variable  missing values  filling factor (%)
# 0                       gross             884           82.470752
# 1                      budget             492           90.243902
# 2                aspect_ratio             329           93.476105
# 3              content_rating             303           93.991672
# 4               plot_keywords             153           96.966092
# 5                  title_year             108           97.858418
# 6               director_name             104           97.937735
# 7     director_facebook_likes             104           97.937735
# 8      num_critic_for_reviews              50           99.008527
# 9      actor_3_facebook_likes              23           99.543922
# 10               actor_3_name              23           99.543922
# 11       num_user_for_reviews              21           99.583581
# 12                      color              19           99.623240
# ...

# %%
movies.dropna()
movies = movies[pd.notnull(movies['actor_1_name'])]
movies = movies[pd.notnull(movies['actor_2_name'])]
movies = movies[pd.notnull(movies['actor_3_name'])]
movies = movies[pd.notnull(movies['director_name'])]
movies = movies[pd.notnull(movies['budget'])]
movies = movies[pd.notnull(movies['content_rating'])]
missing_df = movies.isnull().sum(axis=0).reset_index()
missing_df.columns = ['variable', 'missing values']
missing_df['filling factor (%)']=(movies.shape[0]-missing_df['missing values'])/movies.shape[0]*100
missing_df.sort_values('filling factor (%)').reset_index(drop = True)
# Out:
#                      variable  missing values  filling factor (%)
# 0                       gross             499           88.483730
# 1                aspect_ratio             140           96.768982
# 2               plot_keywords              56           98.707593
# 3      num_critic_for_reviews              14           99.676898
# 4                       color              11           99.746134
# 5        facenumber_in_poster              10           99.769213
# 6                    language               6           99.861528
# 7        num_user_for_reviews               2           99.953843
# 8                  imdb_score               0          100.000000
# 9      actor_2_facebook_likes               0          100.000000
# 10                 title_year               0          100.000000
# 11                     budget               0          100.000000
# 12             content_rating               0          100.000000
# ...

# %%
all_genres = set(movies['genres'].tolist())
all_genres
movies
# Out:
#                  color       director_name  num_critic_for_reviews  duration  \
# 0                Color       James Cameron                   723.0     178.0
# 1                Color      Gore Verbinski                   302.0     169.0
# 2                Color          Sam Mendes                   602.0     148.0
# 3                Color   Christopher Nolan                   813.0     164.0
# 5                Color      Andrew Stanton                   462.0     132.0
# 6                Color           Sam Raimi                   392.0     156.0
# 7                Color        Nathan Greno                   324.0     100.0
# 8                Color         Joss Whedon                   635.0     141.0
# 9                Color         David Yates                   375.0     153.0
# 10               Color         Zack Snyder                   673.0     183.0
# 11               Color        Bryan Singer                   434.0     169.0
# ...

# %%
all_directors = set(movies['director_name'].tolist())
all_directors
len(all_directors)
# Out:
# 1999

# %%
movies = movies[['imdb_score', 'budget', 'content_rating', 'director_name', 'director_facebook_likes', 'actor_3_facebook_likes', 'actor_3_name', 'actor_2_facebook_likes', 'actor_2_name', 'actor_1_facebook_likes', 'actor_1_name', 'cast_total_facebook_likes', 'genres']]
movies.head()
# Out:
#    imdb_score       budget content_rating      director_name  \
# 0         7.9  237000000.0          PG-13      James Cameron
# 1         7.1  300000000.0          PG-13     Gore Verbinski
# 2         6.8  245000000.0          PG-13         Sam Mendes
# 3         8.5  250000000.0          PG-13  Christopher Nolan
# 5         6.6  263700000.0          PG-13     Andrew Stanton
#
#    director_facebook_likes  actor_3_facebook_likes          actor_3_name  \
# 0                      0.0                   855.0             Wes Studi
# 1                    563.0                  1000.0        Jack Davenport
# 2                      0.0                   161.0      Stephanie Sigman
# 3                  22000.0                 23000.0  Joseph Gordon-Levitt
# 5                    475.0                   530.0          Polly Walker
#
#    actor_2_facebook_likes      actor_2_name  actor_1_facebook_likes  \
# 0                   936.0  Joel David Moore                  1000.0
# ...

# %%
top500 = movies.sort_values('imdb_score', ascending = False).head(500)

# top500 = movies.reindex(movies.imdb_score.abs().sort(inplace=False).index)
top500
# Out:
#       imdb_score        budget content_rating          director_name  \
# 1937         9.3  2.500000e+07              R         Frank Darabont
# 3466         9.2  6.000000e+06              R   Francis Ford Coppola
# 2837         9.0  1.300000e+07              R   Francis Ford Coppola
# 66           9.0  1.850000e+08          PG-13      Christopher Nolan
# 3355         8.9  8.000000e+06              R      Quentin Tarantino
# 1874         8.9  2.200000e+07              R       Steven Spielberg
# 4822         8.9  3.500000e+05      Not Rated           Sidney Lumet
# 339          8.9  9.400000e+07          PG-13          Peter Jackson
# 4498         8.9  1.200000e+06       Approved           Sergio Leone
# 836          8.8  5.500000e+07          PG-13        Robert Zemeckis
# 270          8.8  9.300000e+07          PG-13          Peter Jackson
# 97           8.8  1.600000e+08          PG-13      Christopher Nolan
# 683          8.8  6.300000e+07              R          David Fincher
# ...

# %%
for index, row in top500.iterrows():
#     if index > len(top500):
#        break
#     else:
# actor1director
    # file with actor1, director of top 500 rated movies
    f1 = open(str(index)+'-actor1director.txt', 'w')
    f1.write('# all of the actors\n')
    f1.write('actor ' + str(row[10]) + '\n')
    f1.write('\n')
    f1.write('# director name\n')
    f1.write('director ' + str(row[3]) + '\n')
    f1.close()
    
    # file with actor1, genre of top 500 rated movies
    f2 = open(str(index)+'-actor1genre.txt', 'w')
    f2.write('# all of the actors\n')
    f2.write('actor ' + str(row[10]) + '\n')
    f2.write('\n')
    f2.write('# genre\n')
    f2.write('genre ' + str(row[12]) + '\n')
    f2.close()
    
    # file with full assignment
    f3 = open(str(index) + '-fullAssignment.txt', 'w')
    f3.write('# all of the actors\n')
    f3.write('actor ' + str(row[10]) + '\n')
    f3.write('actor ' + str(row[8]) + '\n')
    f3.write('actor ' + str(row[6]) + '\n')
    f3.write('\n')
    f3.write('# director name\n')
    f3.write('director ' + str(row[3]) + '\n')
    f3.write('\n')
    f3.write('# content rating\n')
    f3.write('rating ' + str(row[2]) + '\n')
    f3.write('\n')
    f3.write('# genre\n')
    f3.write('genre ' + str(row[12]) + '\n')
    f3.write('\n')
    f3.write('# budget in dollars\n')
    f3.write('budget ' + str(row[1]) + '\n')
    f3.close

# %%
fileMapping = {}

for index, row in top500.iterrows():
    file1 = str(index)+ '-actor1director.txt'
    file2 = str(index)+ '-actor1genre.txt'
    file3 = str(index) + '-fullAssignment.txt'
    fileMapping[file1] = file3
    fileMapping[file2] = file3

# %%
import pickle

with open('fileMapping.pickle', 'wb') as handle:
    pickle.dump(fileMapping, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
actor_id = 0
actor_name_dict = {}
for actor in all_actors:
    actor_name_dict[actor] = actor_id
    actor_id += 1

len(actor_name_dict)
# Out:
# 6256

# %%
genre_id = 0
genre_dict = {}
for genre in all_genres:
    genre_dict[genre] = genre_id
    genre_id += 1

len(genre_dict)
# Out:
# 22

# %%
def strip_ratings(rating):
    if rating == 'Unrated' or rating == 'NC-17' or rating == 'X' or rating == 'TV-MA':
        return 'R'
    elif rating == 'TV-14':
        return 'PG-13'
    elif rating == 'Approved' or rating == 'TV-PG' or rating == 'Not Rated' or rating == 'Passed' or rating == 'GP' or rating == 'M':
        return 'PG'
    elif rating == 'TV-G' or rating == 'TV-Y' or rating == 'TV-Y7':
        return 'G'
    return rating

movies['content_rating'] = movies['content_rating'].apply(strip_ratings)

# %%
all_content_ratings = set(movies['content_rating'].tolist())

content_id = 0
content_rating_dict = {}
for rating in all_content_ratings:
    content_rating_dict[rating] = content_id
    content_id += 1

len(content_rating_dict)
# Out:
# 4

# %%
director_id = 0
director_name_dict = {}
for director in all_directors:
    director_name_dict[director] = director_id
    director_id += 1

len(director_name_dict)
# Out:
# 1999

# %%
# discretize our data
movies['actor_1_name'] = movies.apply(lambda row: actor_name_dict[row.actor_1_name], axis=1)

# %%
movies['actor_2_name'] = movies.apply(lambda row: actor_name_dict[row.actor_2_name], axis=1)

# %%
movies['actor_3_name'] = movies.apply(lambda row: actor_name_dict[row.actor_3_name], axis=1)

# %%
movies['director_name'] = movies.apply(lambda row: director_name_dict[row.director_name], axis=1)

# %%
movies['genres'] = movies.apply(lambda row: genre_dict[row.genres], axis=1)

# %%
movies['content_rating'] = movies.apply(lambda row: content_rating_dict[row.content_rating], axis=1)

# %%
movies.to_csv('final_data.csv', index=False)

# %%
movies["budget"].fillna(movies["budget"].mean(), inplace=True)
movies.head()
# Out:
#    imdb_score       budget  content_rating  director_name  \
# 0         7.9  237000000.0               1            261
# 1         7.1  300000000.0               1           1149
# 2         6.8  245000000.0               1            842
# 3         8.5  250000000.0               1            365
# 5         6.6  263700000.0               1           1661
#
#    director_facebook_likes  actor_3_facebook_likes  actor_3_name  \
# 0                      0.0                   855.0          5607
# 1                    563.0                  1000.0          4908
# 2                      0.0                   161.0          3416
# 3                  22000.0                 23000.0          1510
# 5                    475.0                   530.0          1251
#
#    actor_2_facebook_likes  actor_2_name  actor_1_facebook_likes  actor_1_name  \
# 0                   936.0          1631                  1000.0           405
# ...

# %%
movies["budget"].mean()
# Out:
# 41181362.17747519

# %%
movies.to_csv('final_data.csv', index=False)

# %%
missing_df = movies.isnull().sum(axis=0).reset_index()
missing_df.columns = ['variable', 'missing values']
missing_df['filling factor (%)']=(movies.shape[0]-missing_df['missing values'])/movies.shape[0]*100
missing_df.sort_values('filling factor (%)').reset_index(drop = True)
# Out:
#                      variable  missing values  filling factor (%)
# 0                  imdb_score               0               100.0
# 1                      budget               0               100.0
# 2              content_rating               0               100.0
# 3               director_name               0               100.0
# 4     director_facebook_likes               0               100.0
# 5      actor_3_facebook_likes               0               100.0
# 6                actor_3_name               0               100.0
# 7      actor_2_facebook_likes               0               100.0
# 8                actor_2_name               0               100.0
# 9      actor_1_facebook_likes               0               100.0
# 10               actor_1_name               0               100.0
# 11  cast_total_facebook_likes               0               100.0
# 12                     genres               0               100.0

# %%
movies["director_facebook_likes"].fillna(movies["director_facebook_likes"].mean(), inplace=True)
movies["actor_3_facebook_likes"].fillna(movies["actor_3_facebook_likes"].mean(), inplace=True)
movies["actor_2_facebook_likes"].fillna(movies["actor_2_facebook_likes"].mean(), inplace=True)
movies["actor_1_facebook_likes"].fillna(movies["actor_1_facebook_likes"].mean(), inplace=True)

# %%
missing_df = movies.isnull().sum(axis=0).reset_index()
missing_df.columns = ['variable', 'missing values']
missing_df['filling factor (%)']=(movies.shape[0]-missing_df['missing values'])/movies.shape[0]*100
missing_df.sort_values('filling factor (%)').reset_index(drop = True)
# Out:
#                      variable  missing values  filling factor (%)
# 0                  imdb_score               0               100.0
# 1                      budget               0               100.0
# 2              content_rating               0               100.0
# 3               director_name               0               100.0
# 4     director_facebook_likes               0               100.0
# 5      actor_3_facebook_likes               0               100.0
# 6                actor_3_name               0               100.0
# 7      actor_2_facebook_likes               0               100.0
# 8                actor_2_name               0               100.0
# 9      actor_1_facebook_likes               0               100.0
# 10               actor_1_name               0               100.0
# 11  cast_total_facebook_likes               0               100.0
# 12                     genres               0               100.0

# %%
movies.to_csv('final_data.csv', index=False)

# %%
count = movies['imdb_score'].value_counts()
count
# Out:
# 6.7    199
# 6.6    179
# 6.5    170
# 7.2    165
# 6.1    164
# 6.4    163
# 6.8    158
# 7.0    155
# 7.1    155
# 6.3    153
# 6.9    153
# 6.2    152
# 7.3    150
# 5.9    135
# 5.8    112
# 6.0    112
# 7.4    111
# 7.6    109
# 7.5    105
# 5.6    103
# 5.7    101
# 7.7     99
# 7.8     93
# 5.5     88
# 5.4     85
# 5.3     82
# 8.0     69
# 7.9     62
# 5.1     62
# 8.1     60
#       ...
# 3.3     14
# 3.8     13
# 3.5     12
# 3.9     11
# 8.6     11
# 3.6     11
# 8.7      8
# 3.4      8
# 3.7      7
# 2.8      7
# 3.1      7
# 2.7      6
# 3.2      5
# 8.9      5
# 8.8      5
# 3.0      4
# 1.9      3
# 2.1      3
# 2.3      3
# 2.9      3
# 2.2      2
# 2.0      2
# 9.0      2
# 2.4      2
# 2.6      2
# 2.5      1
# 9.3      1
# 1.7      1
# 9.2      1
# 1.6      1
# Name: imdb_score, Length: 76, dtype: int64

# %%
import pickle

with open('actors.pickle', 'wb') as handle:
    pickle.dump(actor_name_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('directors.pickle', 'wb') as handle:
    pickle.dump(director_name_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('genre.pickle', 'wb') as handle:
    pickle.dump(genre_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('content_ratings.pickle', 'wb') as handle:
    pickle.dump(content_rating_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
movies
# Out:
#       imdb_score       budget  content_rating  director_name  \
# 0            7.9  237000000.0               1            261
# 1            7.1  300000000.0               1           1149
# 2            6.8  245000000.0               1            842
# 3            8.5  250000000.0               1            365
# 5            6.6  263700000.0               1           1661
# 6            6.2  258000000.0               1             62
# 7            7.8  260000000.0               3            391
# 8            7.5  250000000.0               1           1527
# 9            7.5  250000000.0               3            813
# 10           6.9  250000000.0               1           1949
# 11           6.1  209000000.0               1           1687
# 12           6.7  200000000.0               1           1074
# 13           7.3  225000000.0               1           1149
# 14           6.5  215000000.0               1           1149
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
import pickle
from sklearn.externals import joblib

forest = joblib.load('model.pkl')
forest.predict([[185000000.0,2,436,0,0,0,12]])


# [['budget', 'content_rating', 'director_name', 'actor_3_name', 'actor_2_name', 'actor_1_name', 'genres']]

# budget 185000000.0
# content rating 2
# director name 436
# genre 12
# actor_1_name 4913
# actor_2_name 438
# actor 3 name 3865
# Out:
# array([ 6.48])

# %%
actor_name_dict
# Out:
# {'Richard Epcar': 1693,
#  'Rick Fox': 2,
#  'Stephanie March': 3,
#  'Sean Keenan': 4,
#  'Khamani Griffin': 5,
#  'Jacki Weaver': 6,
#  'Gilbert Roland': 7,
#  'Luis Sanchez': 3247,
#  'Lymari Nadal': 8,
#  'Renee Faia': 57,
#  'Mindy Kaling': 10,
#  'Harold Perrineau': 3845,
#  'Hye-kyo Song': 11,
#  'Gladys Cooper': 3276,
#  'Frances Fisher': 13,
#  'Erick Avari': 14,
#  'Kevork Malikyan': 16,
#  "Judith O'Dea": 17,
#  'James Le Gros': 18,
#  'Ayelet Zurer': 19,
#  'Dom DeLuise': 20,
#  'Cara Delevingne': 3434,
#  'Alex Karpovsky': 23,
#  'Reba McEntire': 24,
#  'Natascha McElhone': 4343,
#  'Tyra Banks': 25,
#  'Tiya Sircar': 26,
#  'Matthew Cowles': 27,
#  'Doug Bradley': 156,
#  'Melina Kanakaredes': 1696,
#  'Eddie Griffin': 30,
#  'Sean Maher': 31,
#  'Essence Atkins': 32,
#  'Pamela Anderson': 33,
#  'Jimi Mistry': 34,
#  'Anil Kapoor': 35,
#  'Ari Graynor': 36,
#  'Kevin Tighe': 3200,
#  'Dorothy Lyman': 37,
#  'Aramis Knight': 4598,
#  'Denis Lavant': 38,
# ...

# %%
count = movies['director_name'].value_counts()
count
# Out:
# 1088    26
# 1266    22
# 1603    20
# 1253    18
# 1032    17
# 1485    16
# 1690    16
# 1631    15
# 564     15
# 1460    14
# 1441    13
# 1182    13
# 1471    13
# 1757    13
# 1093    13
# 62      13
# 1797    13
# 27      12
# 516     12
# 1706    12
# 347     12
# 1934    12
# 1077    12
# 947     12
# 755     12
# 785     11
# 975     11
# 1886    11
# 1537    11
# 961     11
#         ..
# 822      1
# 826      1
# 830      1
# 846      1
# 850      1
# 854      1
# 710      1
# 706      1
# 702      1
# 698      1
# 582      1
# 598      1
# 606      1
# 610      1
# 614      1
# 622      1
# 626      1
# 638      1
# 642      1
# 646      1
# 654      1
# 658      1
# 662      1
# 670      1
# 674      1
# 678      1
# 682      1
# 690      1
# 694      1
# 0        1
# Name: director_name, Length: 1999, dtype: int64

# %%
all_genres
# Out:
# {'Action',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'Romance',
#  'Sci-Fi',
#  'Sport',
#  'Thriller',
#  'War',
#  'Western'}

# %%
actor_name_dict
# Out:
# {'Richard Epcar': 1693,
#  'Rick Fox': 2,
#  'Stephanie March': 3,
#  'Sean Keenan': 4,
#  'Khamani Griffin': 5,
#  'Jacki Weaver': 6,
#  'Gilbert Roland': 7,
#  'Luis Sanchez': 3247,
#  'Lymari Nadal': 8,
#  'Renee Faia': 57,
#  'Mindy Kaling': 10,
#  'Harold Perrineau': 3845,
#  'Hye-kyo Song': 11,
#  'Gladys Cooper': 3276,
#  'Frances Fisher': 13,
#  'Erick Avari': 14,
#  'Kevork Malikyan': 16,
#  "Judith O'Dea": 17,
#  'James Le Gros': 18,
#  'Ayelet Zurer': 19,
#  'Dom DeLuise': 20,
#  'Cara Delevingne': 3434,
#  'Alex Karpovsky': 23,
#  'Reba McEntire': 24,
#  'Natascha McElhone': 4343,
#  'Tyra Banks': 25,
#  'Tiya Sircar': 26,
#  'Matthew Cowles': 27,
#  'Doug Bradley': 156,
#  'Melina Kanakaredes': 1696,
#  'Eddie Griffin': 30,
#  'Sean Maher': 31,
#  'Essence Atkins': 32,
#  'Pamela Anderson': 33,
#  'Jimi Mistry': 34,
#  'Anil Kapoor': 35,
#  'Ari Graynor': 36,
#  'Kevin Tighe': 3200,
#  'Dorothy Lyman': 37,
#  'Aramis Knight': 4598,
#  'Denis Lavant': 38,
# ...

# %%
count = movies['director_name'].value_counts()
count
# Out:
# 1088    26
# 1266    22
# 1603    20
# 1253    18
# 1032    17
# 1485    16
# 1690    16
# 1631    15
# 564     15
# 1460    14
# 1441    13
# 1182    13
# 1471    13
# 1757    13
# 1093    13
# 62      13
# 1797    13
# 27      12
# 516     12
# 1706    12
# 347     12
# 1934    12
# 1077    12
# 947     12
# 755     12
# 785     11
# 975     11
# 1886    11
# 1537    11
# 961     11
#         ..
# 822      1
# 826      1
# 830      1
# 846      1
# 850      1
# 854      1
# 710      1
# 706      1
# 702      1
# 698      1
# 582      1
# 598      1
# 606      1
# 610      1
# 614      1
# 622      1
# 626      1
# 638      1
# 642      1
# 646      1
# 654      1
# 658      1
# 662      1
# 670      1
# 674      1
# 678      1
# 682      1
# 690      1
# 694      1
# 0        1
# Name: director_name, Length: 1999, dtype: int64

# %%
# Out:
# {'Action': 15,
#  'Adventure': 12,
#  'Animation': 3,
#  'Biography': 22,
#  'Comedy': 5,
#  'Crime': 1,
#  'Documentary': 16,
#  'Drama': 14,
#  'Family': 19,
#  'Fantasy': 20,
#  'Film-Noir': 8,
#  'History': 18,
#  'Horror': 7,
#  'Music': 4,
#  'Musical': 17,
#  'Mystery': 13,
#  'News': 10,
#  'Romance': 2,
#  'Sci-Fi': 0,
#  'Sport': 21,
#  'Thriller': 11,
#  'War': 6,
#  'Western': 9}
